# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the random module.
import random

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 724

# %%
# Import the requests library.
import requests

# Import the API key.
import os
os.chdir('..')
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    
    # Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 15 | port alfred
# Processing Record 2 of Set 15 | padang
# Processing Record 3 of Set 15 | yulara
# Processing Record 4 of Set 15 | ponta do sol
# Processing Record 5 of Set 15 | busselton
# Processing Record 6 of Set 15 | oliveira dos brejinhos
# Processing Record 7 of Set 15 | ushuaia
# Processing Record 8 of Set 15 | chokurdakh
# Processing Record 9 of Set 15 | upington
# Processing Record 10 of Set 15 | xichang
# Processing Record 11 of Set 15 | san quintin
# Processing Record 12 of Set 15 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 15 | iquitos
# Processing Record 14 of Set 15 | sosnogorsk
# Processing Record 15 of Set 15 | albany
# Processing Record 16 of Set 15 | rikitea
# Processing Record 17 of Set 15 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 15 | barrow
# Processing Record 19 of Set 15 | kodiak
# Processing Record 20 of Set 15 | atlantic beach
# Processing Record 21 of Set 15 | iqaluit
# Processing Record 22 of Set 15 | dikson
# Processing Record 23 of Set 15 | jamestown
# Processing Record 24 of Set 15 | ancud
# Processing Record 25 of Set 15 | sorland
# Processing Record 26 of Set 15 | krasnogvardeyskiy
# Processing Record 27 of Set 15 | hermanus
# Processing Record 28 of Set 15 | klaksvik
# Processing Record 29 of Set 15 | bemidji
# Processing Record 30 of Set 15 | tasiilaq
# Processing Record 31 of Set 15 | punta arenas
# Processing Record 32 of Set 15 | christchurch
# Processing Record 33 of Set 15 | atuona
# Processing Record 34 of Set 15 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 15 | zonguldak
# Processing Record 36 of Set 15 | tuktoyaktuk
# Processing Record 37 of Set 15 | mar del plata
# Processing Record 38 of Set 15 | karakol
# Processing Record 39 of Set 15 | terrace bay
# Processing Record 40 of Set 15 | kastamonu
# Processing Record 41 of Set 15 | riyadh
# Processing Record 42 of Set 15 | port elizabeth
# Processing Record 43 of Set 15 | hobart
# Processing Record 44 of Set 15 | san patricio
# Processing Record 45 of Set 15 | butaritari
# Processing Record 46 of Set 15 | slave lake
# Processing Record 47 of Set 15 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 15 | carnarvon
# Processing Record 49 of Set 15 | naryan-mar
# Processing Record 50 of Set 15 | new norfolk
# Processing Record 1 of Set 16 | raudeberg
# Processing Record 2 of Set 16 | kapaa
# Processing Record 3 of Set 16 | sept-iles
# Processing Record 4 of Set 16 | vaini
# Processing Record 5 of Set 16 | delicias
# Processing Record 6 of Set 16 | yining
# Processing Record 7 of Set 16 | cayenne
# Processing Record 8 of Set 16 | lompoc
# Processing Record 9 of Set 16 | saint-philippe
# Processing Record 10 of Set 16 | suraabad
# Processing Record 11 of Set 16 | garissa
# Processing Record 12 of Set 16 | lebu
# Processing Record 13 of Set 16 | kawana waters
# City not found. Skipping...
# Processing Record 14 of Set 16 | coffs harbour
# Processing Record 15 of Set 16 | qaanaaq
# Processing Record 16 of Set 16 | alugan
# Processing Record 17 of Set 16 | belaya gora
# Processing Record 18 of Set 16 | upernavik
# Processing Record 19 of Set 16 | saint-ambroise
# Processing Record 20 of Set 16 | balimo
# City not found. Skipping...
# Processing Record 21 of Set 16 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 16 | namwala
# Processing Record 23 of Set 16 | chagda
# City not found. Skipping...
# Processing Record 24 of Set 16 | copiapo
# Processing Record 25 of Set 16 | antofagasta
# Processing Record 26 of Set 16 | alofi
# Processing Record 27 of Set 16 | bengkulu
# Processing Record 28 of Set 16 | castro
# Processing Record 29 of Set 16 | asyut
# Processing Record 30 of Set 16 | alta floresta
# Processing Record 31 of Set 16 | bayanday
# Processing Record 32 of Set 16 | yellowknife
# Processing Record 33 of Set 16 | kahului
# Processing Record 34 of Set 16 | falam
# Processing Record 35 of Set 16 | karachi
# Processing Record 36 of Set 16 | chuy
# Processing Record 37 of Set 16 | katsuura
# Processing Record 38 of Set 16 | naco
# Processing Record 39 of Set 16 | brae
# Processing Record 40 of Set 16 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 16 | damietta
# Processing Record 42 of Set 16 | santa rosa
# Processing Record 43 of Set 16 | sorvag
# City not found. Skipping...
# Processing Record 44 of Set 16 | yar-sale
# Processing Record 45 of Set 16 | tuatapere
# Processing Record 46 of Set 16 | ostrovnoy
# Processing Record 47 of Set 16 | rio claro
# Processing Record 48 of Set 16 | numi
# City not found. Skipping...
# Processing Record 49 of Set 16 | victoria
# Processing Record 50 of Set 16 | navrongo
# Processing Record 1 of Set 17 | kofele
# Processing Record 2 of Set 17 | jurado
# Processing Record 3 of Set 17 | mataura
# Processing Record 4 of Set 17 | bredasdorp
# Processing Record 5 of Set 17 | isangel
# Processing Record 6 of Set 17 | ixtapa
# Processing Record 7 of Set 17 | burnie
# Processing Record 8 of Set 17 | amahai
# Processing Record 9 of Set 17 | krasnyy oktyabr
# Processing Record 10 of Set 17 | sur
# Processing Record 11 of Set 17 | talnakh
# Processing Record 12 of Set 17 | havre-saint-pierre
# Processing Record 13 of Set 17 | madang
# Processing Record 14 of Set 17 | tabou
# Processing Record 15 of Set 17 | vardo
# Processing Record 16 of Set 17 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 17 | lakselv
# Processing Record 18 of Set 17 | ahipara
# Processing Record 19 of Set 17 | tautira
# Processing Record 20 of Set 17 | cape town
# Processing Record 21 of Set 17 | khatanga
# Processing Record 22 of Set 17 | pisco
# Processing Record 23 of Set 17 | saskylakh
# Processing Record 24 of Set 17 | portland
# Processing Record 25 of Set 17 | provideniya
# Processing Record 26 of Set 17 | nakhon phanom
# Processing Record 27 of Set 17 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 17 | kurilsk
# Processing Record 29 of Set 17 | tilichiki
# Processing Record 30 of Set 17 | kuching
# Processing Record 31 of Set 17 | hilo
# Processing Record 32 of Set 17 | kaeo
# Processing Record 33 of Set 17 | bluff
# Processing Record 34 of Set 17 | tiksi
# Processing Record 35 of Set 17 | los llanos de aridane
# Processing Record 36 of Set 17 | luderitz
# Processing Record 37 of Set 17 | kolosovka
# Processing Record 38 of Set 17 | cape elizabeth
# City not found. Skipping...
# Processing Record 39 of Set 17 | bubaque
# Processing Record 40 of Set 17 | sangin
# Processing Record 41 of Set 17 | east london
# Processing Record 42 of Set 17 | vanimo
# Processing Record 43 of Set 17 | fort nelson
# Processing Record 44 of Set 17 | abbeville
# Processing Record 45 of Set 17 | solovetskiy
# City not found. Skipping...
# Processing Record 46 of Set 17 | portales
# Processing Record 47 of Set 17 | taozhuang
# Processing Record 48 of Set 17 | linxia
# Processing Record 49 of Set 17 | hithadhoo
# Processing Record 50 of Set 17 | fajardo
# Processing Record 1 of Set 18 | dakar
# Processing Record 2 of Set 18 | fortuna
# Processing Record 3 of Set 18 | palmer
# Processing Record 4 of Set 18 | louisbourg
# City not found. Skipping...
# Processing Record 5 of Set 18 | arroyohondo
# Processing Record 6 of Set 18 | saint anthony
# Processing Record 7 of Set 18 | avarua
# Processing Record 8 of Set 18 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 18 | maniitsoq
# Processing Record 10 of Set 18 | dire dawa
# Processing Record 11 of Set 18 | wodonga
# Processing Record 12 of Set 18 | sao joao da barra
# Processing Record 13 of Set 18 | tartus
# Processing Record 14 of Set 18 | arraial do cabo
# Processing Record 15 of Set 18 | torbay
# Processing Record 16 of Set 18 | sibolga
# Processing Record 17 of Set 18 | mawlaik
# Processing Record 18 of Set 18 | erzin
# Processing Record 19 of Set 18 | tijara
# Processing Record 20 of Set 18 | dauriya
# Processing Record 21 of Set 18 | port macquarie
# Processing Record 22 of Set 18 | agadir
# Processing Record 23 of Set 18 | bathsheba
# Processing Record 24 of Set 18 | talavera de la reina
# Processing Record 25 of Set 18 | poum
# Processing Record 26 of Set 18 | deputatskiy
# Processing Record 27 of Set 18 | alice springs
# Processing Record 28 of Set 18 | jalu
# Processing Record 29 of Set 18 | mount gambier
# Processing Record 30 of Set 18 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 18 | milingimbi
# City not found. Skipping...
# Processing Record 32 of Set 18 | przhevalskoye
# Processing Record 33 of Set 18 | cabo san lucas
# Processing Record 34 of Set 18 | rawannawi
# City not found. Skipping...
# Processing Record 35 of Set 18 | kandrian
# Processing Record 36 of Set 18 | punta alta
# Processing Record 37 of Set 18 | taksimo
# Processing Record 38 of Set 18 | surt
# Processing Record 39 of Set 18 | nago
# Processing Record 40 of Set 18 | teya
# Processing Record 41 of Set 18 | saint-leu
# Processing Record 42 of Set 18 | marsabit
# Processing Record 43 of Set 18 | puerto escondido
# Processing Record 44 of Set 18 | puerto ayora
# Processing Record 45 of Set 18 | cidreira
# Processing Record 46 of Set 18 | hasaki
# Processing Record 47 of Set 18 | thompson
# Processing Record 48 of Set 18 | srednekolymsk
# Processing Record 49 of Set 18 | bagdarin
# Processing Record 50 of Set 18 | waingapu
# Processing Record 1 of Set 19 | narsaq
# Processing Record 2 of Set 19 | krasnoselkup
# Processing Record 3 of Set 19 | ati
# Processing Record 4 of Set 19 | bambanglipuro
# Processing Record 5 of Set 19 | jupiter
# Processing Record 6 of Set 19 | ingham
# Processing Record 7 of Set 19 | cockburn town
# Processing Record 8 of Set 19 | bowen
# Processing Record 9 of Set 19 | scottsbluff
# Processing Record 10 of Set 19 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 19 | lavrentiya
# Processing Record 12 of Set 19 | lorengau
# Processing Record 13 of Set 19 | bababe
# City not found. Skipping...
# Processing Record 14 of Set 19 | bitung
# Processing Record 15 of Set 19 | meulaboh
# Processing Record 16 of Set 19 | gerash
# Processing Record 17 of Set 19 | touros
# Processing Record 18 of Set 19 | huarmey
# Processing Record 19 of Set 19 | verkhnetulomskiy
# Processing Record 20 of Set 19 | gurgentepe
# Processing Record 21 of Set 19 | rostov
# Processing Record 22 of Set 19 | pevek
# Processing Record 23 of Set 19 | niquelandia
# Processing Record 24 of Set 19 | karaul
# City not found. Skipping...
# Processing Record 25 of Set 19 | sisimiut
# Processing Record 26 of Set 19 | vao
# Processing Record 27 of Set 19 | sabha
# Processing Record 28 of Set 19 | chimbote
# Processing Record 29 of Set 19 | broome
# Processing Record 30 of Set 19 | portobelo
# Processing Record 31 of Set 19 | mustafakemalpasa
# Processing Record 32 of Set 19 | koshurnikovo
# Processing Record 33 of Set 19 | pasinler
# Processing Record 34 of Set 19 | pangai
# Processing Record 35 of Set 19 | longyearbyen
# Processing Record 36 of Set 19 | saint-pierre
# Processing Record 37 of Set 19 | vaitape
# Processing Record 38 of Set 19 | sao geraldo do araguaia
# Processing Record 39 of Set 19 | boz
# Processing Record 40 of Set 19 | havoysund
# Processing Record 41 of Set 19 | jiddah
# City not found. Skipping...
# Processing Record 42 of Set 19 | lasa
# Processing Record 43 of Set 19 | madanapalle
# Processing Record 44 of Set 19 | dunedin
# Processing Record 45 of Set 19 | ribeira grande
# Processing Record 46 of Set 19 | faanui
# Processing Record 47 of Set 19 | omsukchan
# Processing Record 48 of Set 19 | hami
# Processing Record 49 of Set 19 | igrim
# Processing Record 50 of Set 19 | matadi
# Processing Record 1 of Set 20 | biggar
# Processing Record 2 of Set 20 | atkinson
# Processing Record 3 of Set 20 | nikolskoye
# Processing Record 4 of Set 20 | loubomo
# Processing Record 5 of Set 20 | calama
# Processing Record 6 of Set 20 | andevoranto
# City not found. Skipping...
# Processing Record 7 of Set 20 | alotau
# City not found. Skipping...
# Processing Record 8 of Set 20 | saldanha
# Processing Record 9 of Set 20 | lata
# Processing Record 10 of Set 20 | bismarck
# Processing Record 11 of Set 20 | malwan
# City not found. Skipping...
# Processing Record 12 of Set 20 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 20 | ilhabela
# Processing Record 14 of Set 20 | severo-kurilsk
# Processing Record 15 of Set 20 | loikaw
# Processing Record 16 of Set 20 | colares
# Processing Record 17 of Set 20 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 20 | la ronge
# Processing Record 19 of Set 20 | vestmannaeyjar
# Processing Record 20 of Set 20 | cortes
# Processing Record 21 of Set 20 | norman wells
# Processing Record 22 of Set 20 | tambun
# Processing Record 23 of Set 20 | souillac
# Processing Record 24 of Set 20 | mahebourg
# Processing Record 25 of Set 20 | cam pha
# City not found. Skipping...
# Processing Record 26 of Set 20 | egvekinot
# Processing Record 27 of Set 20 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 20 | flic en flac
# Processing Record 29 of Set 20 | namatanai
# Processing Record 30 of Set 20 | seini
# Processing Record 31 of Set 20 | kailua
# Processing Record 32 of Set 20 | tanete
# Processing Record 33 of Set 20 | adeje
# Processing Record 34 of Set 20 | vostok
# Processing Record 35 of Set 20 | gulbene
# Processing Record 36 of Set 20 | matara
# Processing Record 37 of Set 20 | dingle
# Processing Record 38 of Set 20 | pleshanovo
# Processing Record 39 of Set 20 | marawi
# Processing Record 40 of Set 20 | sembakung
# Processing Record 41 of Set 20 | college
# Processing Record 42 of Set 20 | ajra
# Processing Record 43 of Set 20 | ibirama
# Processing Record 44 of Set 20 | bambous virieux
# Processing Record 45 of Set 20 | kazachinskoye
# Processing Record 46 of Set 20 | kudahuvadhoo
# Processing Record 47 of Set 20 | suriapet
# Processing Record 48 of Set 20 | challans
# Processing Record 49 of Set 20 | teahupoo
# Processing Record 50 of Set 20 | husavik
# Processing Record 1 of Set 21 | sahaspur
# Processing Record 2 of Set 21 | skjervoy
# Processing Record 3 of Set 21 | kenai
# Processing Record 4 of Set 21 | sao filipe
# Processing Record 5 of Set 21 | patan
# Processing Record 6 of Set 21 | kaitangata
# Processing Record 7 of Set 21 | chingirlau
# Processing Record 8 of Set 21 | brandfort
# Processing Record 9 of Set 21 | tanout
# Processing Record 10 of Set 21 | koumac
# Processing Record 11 of Set 21 | melilla
# Processing Record 12 of Set 21 | guerrero negro
# Processing Record 13 of Set 21 | tonj
# Processing Record 14 of Set 21 | imbituba
# Processing Record 15 of Set 21 | monte patria
# Processing Record 16 of Set 21 | constitucion
# Processing Record 17 of Set 21 | goure
# Processing Record 18 of Set 21 | richards bay
# Processing Record 19 of Set 21 | makakilo city
# Processing Record 20 of Set 21 | halalo
# City not found. Skipping...
# Processing Record 21 of Set 21 | lapua
# Processing Record 22 of Set 21 | anadyr
# Processing Record 23 of Set 21 | abnub
# Processing Record 24 of Set 21 | inhambane
# Processing Record 25 of Set 21 | lazaro cardenas
# Processing Record 26 of Set 21 | bima
# Processing Record 27 of Set 21 | umm lajj
# Processing Record 28 of Set 21 | tura
# Processing Record 29 of Set 21 | liniere
# City not found. Skipping...
# Processing Record 30 of Set 21 | georgetown
# Processing Record 31 of Set 21 | micheweni
# Processing Record 32 of Set 21 | yanan
# City not found. Skipping...
# Processing Record 33 of Set 21 | independence
# Processing Record 34 of Set 21 | bethel
# Processing Record 35 of Set 21 | urdzhar
# City not found. Skipping...
# Processing Record 36 of Set 21 | rognan
# Processing Record 37 of Set 21 | channel-port aux basques
# Processing Record 38 of Set 21 | airai
# Processing Record 39 of Set 21 | baoqing
# Processing Record 40 of Set 21 | balkanabat
# Processing Record 41 of Set 21 | opuwo
# Processing Record 42 of Set 21 | kabare
# Processing Record 43 of Set 21 | acapulco
# Processing Record 44 of Set 21 | berlevag
# Processing Record 45 of Set 21 | keetmanshoop
# Processing Record 46 of Set 21 | sheoganj
# Processing Record 47 of Set 21 | paamiut
# Processing Record 48 of Set 21 | madison
# Processing Record 49 of Set 21 | changde
# Processing Record 50 of Set 21 | beatrice
# Processing Record 1 of Set 22 | bandarbeyla
# Processing Record 2 of Set 22 | tolbazy
# Processing Record 3 of Set 22 | oktyabrskoye
# Processing Record 4 of Set 22 | gizo
# Processing Record 5 of Set 22 | bafra
# Processing Record 6 of Set 22 | coquimbo
# Processing Record 7 of Set 22 | chumikan
# Processing Record 8 of Set 22 | erenhot
# Processing Record 9 of Set 22 | vanderhoof
# Processing Record 10 of Set 22 | mopti
# Processing Record 11 of Set 22 | san jose de sisa
# Processing Record 12 of Set 22 | bolungarvik
# City not found. Skipping...
# Processing Record 13 of Set 22 | zaplyusye
# City not found. Skipping...
# Processing Record 14 of Set 22 | adrar
# Processing Record 15 of Set 22 | mayo
# Processing Record 16 of Set 22 | acurenam
# Processing Record 17 of Set 22 | aanekoski
# Processing Record 18 of Set 22 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 22 | manado
# Processing Record 20 of Set 22 | oranjestad
# Processing Record 21 of Set 22 | verkh-usugli
# Processing Record 22 of Set 22 | kamenka
# Processing Record 23 of Set 22 | puerto cortes
# City not found. Skipping...
# Processing Record 24 of Set 22 | lillehammer
# Processing Record 25 of Set 22 | kedrovyy
# Processing Record 26 of Set 22 | sosua
# Processing Record 27 of Set 22 | rabat
# Processing Record 28 of Set 22 | monte cristi
# City not found. Skipping...
# Processing Record 29 of Set 22 | nampa
# Processing Record 30 of Set 22 | arkhangelsk
# Processing Record 31 of Set 22 | saint george
# Processing Record 32 of Set 22 | tecoanapa
# Processing Record 33 of Set 22 | bilma
# Processing Record 34 of Set 22 | nanortalik
# Processing Record 35 of Set 22 | juegang
# Processing Record 36 of Set 22 | aklavik
# Processing Record 37 of Set 22 | frontera comalapa
# Processing Record 38 of Set 22 | lagoa
# Processing Record 39 of Set 22 | beloha
# Processing Record 40 of Set 22 | marsa matruh
# Processing Record 41 of Set 22 | sabang
# Processing Record 42 of Set 22 | pahrump
# Processing Record 43 of Set 22 | megion
# Processing Record 44 of Set 22 | kavieng
# Processing Record 45 of Set 22 | coihaique
# Processing Record 46 of Set 22 | dobre miasto
# Processing Record 47 of Set 22 | nouakchott
# Processing Record 48 of Set 22 | bodoco
# City not found. Skipping...
# Processing Record 49 of Set 22 | sarankhola
# Processing Record 50 of Set 22 | kaka
# Processing Record 1 of Set 23 | san lazaro
# Processing Record 2 of Set 23 | te anau
# Processing Record 3 of Set 23 | qiongshan
# Processing Record 4 of Set 23 | puerto colombia
# Processing Record 5 of Set 23 | grand centre
# City not found. Skipping...
# Processing Record 6 of Set 23 | trairi
# Processing Record 7 of Set 23 | vila velha
# Processing Record 8 of Set 23 | nuuk
# Processing Record 9 of Set 23 | port lincoln
# Processing Record 10 of Set 23 | ritchie
# Processing Record 11 of Set 23 | marsh harbour
# Processing Record 12 of Set 23 | pemberton
# Processing Record 13 of Set 23 | ahome
# Processing Record 14 of Set 23 | san policarpo
# Processing Record 15 of Set 23 | male
# Processing Record 16 of Set 23 | gat
# Processing Record 17 of Set 23 | kargopol
# Processing Record 18 of Set 23 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 23 | san carlos de bariloche
# Processing Record 20 of Set 23 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 23 | luwuk
# Processing Record 22 of Set 23 | ola
# Processing Record 23 of Set 23 | katherine
# Processing Record 24 of Set 23 | chaplynka
# Processing Record 25 of Set 23 | terrace
# Processing Record 26 of Set 23 | caravelas
# Processing Record 27 of Set 23 | serra branca
# Processing Record 28 of Set 23 | gunjur
# Processing Record 29 of Set 23 | moose factory
# Processing Record 30 of Set 23 | murygino
# Processing Record 31 of Set 23 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 23 | pandan
# Processing Record 33 of Set 23 | esmeralda
# Processing Record 34 of Set 23 | kuytun
# Processing Record 35 of Set 23 | kavaratti
# Processing Record 36 of Set 23 | abay
# Processing Record 37 of Set 23 | batagay-alyta
# Processing Record 38 of Set 23 | kapuskasing
# Processing Record 39 of Set 23 | svetlogorsk
# Processing Record 40 of Set 23 | port-cartier
# Processing Record 41 of Set 23 | vila do maio
# Processing Record 42 of Set 23 | hirson
# Processing Record 43 of Set 23 | roma
# Processing Record 44 of Set 23 | san jose
# Processing Record 45 of Set 23 | nikolsk
# Processing Record 46 of Set 23 | belyy yar
# Processing Record 47 of Set 23 | cruz grande
# Processing Record 48 of Set 23 | nipawin
# Processing Record 49 of Set 23 | matane
# Processing Record 50 of Set 23 | kamina
# Processing Record 1 of Set 24 | miranorte
# City not found. Skipping...
# Processing Record 2 of Set 24 | ketchikan
# Processing Record 3 of Set 24 | pontarlier
# Processing Record 4 of Set 24 | olivenza
# Processing Record 5 of Set 24 | hearst
# Processing Record 6 of Set 24 | manggar
# Processing Record 7 of Set 24 | kalmunai
# Processing Record 8 of Set 24 | ciras
# City not found. Skipping...
# Processing Record 9 of Set 24 | praya
# Processing Record 10 of Set 24 | mount isa
# Processing Record 11 of Set 24 | yinchuan
# Processing Record 12 of Set 24 | denpasar
# Processing Record 13 of Set 24 | paita
# Processing Record 14 of Set 24 | walvis bay
# Processing Record 15 of Set 24 | castletown
# Processing Record 16 of Set 24 | galiwinku
# City not found. Skipping...
# Processing Record 17 of Set 24 | dukat
# Processing Record 18 of Set 24 | luanda
# Processing Record 19 of Set 24 | salalah
# Processing Record 20 of Set 24 | hamilton
# Processing Record 21 of Set 24 | guane
# Processing Record 22 of Set 24 | rosetta
# Processing Record 23 of Set 24 | chenghai
# Processing Record 24 of Set 24 | kichera
# Processing Record 25 of Set 24 | clyde river
# Processing Record 26 of Set 24 | krasnokamensk
# Processing Record 27 of Set 24 | esperance
# Processing Record 28 of Set 24 | coyah
# Processing Record 29 of Set 24 | hualmay
# Processing Record 30 of Set 24 | borzya
# Processing Record 31 of Set 24 | amot
# Processing Record 32 of Set 24 | kutum
# Processing Record 33 of Set 24 | dukhovshchina
# Processing Record 34 of Set 24 | tashla
# Processing Record 35 of Set 24 | labuhan
# Processing Record 36 of Set 24 | fallon
# Processing Record 37 of Set 24 | sakete
# Processing Record 38 of Set 24 | turukhansk
# Processing Record 39 of Set 24 | liverpool
# Processing Record 40 of Set 24 | quatre cocos
# Processing Record 41 of Set 24 | sao francisco de paula
# Processing Record 42 of Set 24 | cherskiy
# Processing Record 43 of Set 24 | broken hill
# Processing Record 44 of Set 24 | bone
# Processing Record 45 of Set 24 | fairbanks
# Processing Record 46 of Set 24 | ulladulla
# Processing Record 47 of Set 24 | charters towers
# Processing Record 48 of Set 24 | zeulenroda
# Processing Record 49 of Set 24 | geraldton
# Processing Record 50 of Set 24 | river falls
# Processing Record 1 of Set 25 | changping
# Processing Record 2 of Set 25 | olinda
# Processing Record 3 of Set 25 | san cristobal
# Processing Record 4 of Set 25 | magliz
# City not found. Skipping...
# Processing Record 5 of Set 25 | ternate
# Processing Record 6 of Set 25 | burica
# City not found. Skipping...
# Processing Record 7 of Set 25 | indianola
# Processing Record 8 of Set 25 | ceres
# Processing Record 9 of Set 25 | gurskoye
# City not found. Skipping...
# Processing Record 10 of Set 25 | bosaso
# Processing Record 11 of Set 25 | buala
# Processing Record 12 of Set 25 | dolbeau
# City not found. Skipping...
# Processing Record 13 of Set 25 | arlit
# Processing Record 14 of Set 25 | karlskoga
# Processing Record 15 of Set 25 | valdosta
# Processing Record 16 of Set 25 | kovur
# Processing Record 17 of Set 25 | shchelyayur
# City not found. Skipping...
# Processing Record 18 of Set 25 | pangnirtung
# Processing Record 19 of Set 25 | kolokani
# Processing Record 20 of Set 25 | the valley
# Processing Record 21 of Set 25 | pacific grove
# Processing Record 22 of Set 25 | codrington
# Processing Record 23 of Set 25 | morant bay
# Processing Record 24 of Set 25 | plastun
# Processing Record 25 of Set 25 | khorixas
# Processing Record 26 of Set 25 | xique-xique
# Processing Record 27 of Set 25 | talara
# Processing Record 28 of Set 25 | vestbygda
# City not found. Skipping...
# Processing Record 29 of Set 25 | lunglei
# Processing Record 30 of Set 25 | vagur
# Processing Record 31 of Set 25 | karasuk
# Processing Record 32 of Set 25 | priargunsk
# Processing Record 33 of Set 25 | mocuba
# Processing Record 34 of Set 25 | skibbereen
# Processing Record 35 of Set 25 | batemans bay
# Processing Record 36 of Set 25 | xucheng
# Processing Record 37 of Set 25 | kalengwa
# Processing Record 38 of Set 25 | mabaruma
# Processing Record 39 of Set 25 | salinopolis
# Processing Record 40 of Set 25 | qaqortoq
# Processing Record 41 of Set 25 | solsvik
# City not found. Skipping...
# Processing Record 42 of Set 25 | manta
# Processing Record 43 of Set 25 | buin
# Processing Record 44 of Set 25 | fagersta
# Processing Record 45 of Set 25 | arvi
# Processing Record 46 of Set 25 | carupano
# Processing Record 47 of Set 25 | tahe
# Processing Record 48 of Set 25 | purworejo
# Processing Record 49 of Set 25 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 25 | abha
# Processing Record 1 of Set 26 | tiznit
# Processing Record 2 of Set 26 | giyon
# Processing Record 3 of Set 26 | pinega
# Processing Record 4 of Set 26 | necochea
# Processing Record 5 of Set 26 | kontagora
# Processing Record 6 of Set 26 | wer
# Processing Record 7 of Set 26 | taoudenni
# Processing Record 8 of Set 26 | general roca
# Processing Record 9 of Set 26 | tezu
# Processing Record 10 of Set 26 | oak ridge
# Processing Record 11 of Set 26 | hamburg
# Processing Record 12 of Set 26 | kabale
# Processing Record 13 of Set 26 | belmonte
# Processing Record 14 of Set 26 | goderich
# Processing Record 15 of Set 26 | villa maria
# Processing Record 16 of Set 26 | porto seguro
# Processing Record 17 of Set 26 | dawlatabad
# Processing Record 18 of Set 26 | kozhevnikovo
# Processing Record 19 of Set 26 | mnogovershinnyy
# Processing Record 20 of Set 26 | altamira
# Processing Record 21 of Set 26 | woodstock
# Processing Record 22 of Set 26 | zig
# Processing Record 23 of Set 26 | churapcha
# Processing Record 24 of Set 26 | novyy urengoy
# Processing Record 25 of Set 26 | tsabong
# Processing Record 26 of Set 26 | yabrud
# Processing Record 27 of Set 26 | barra patuca
# Processing Record 28 of Set 26 | bilibino
# Processing Record 29 of Set 26 | vasudevanallur
# Processing Record 30 of Set 26 | villa carlos paz
# Processing Record 31 of Set 26 | marmaron
# City not found. Skipping...
# Processing Record 32 of Set 26 | aykhal
# Processing Record 33 of Set 26 | aljezur
# Processing Record 34 of Set 26 | anqiu
# Processing Record 35 of Set 26 | iguape
# Processing Record 36 of Set 26 | kruisfontein
# Processing Record 37 of Set 26 | mbandaka
# Processing Record 38 of Set 26 | dunmore east
# Processing Record 39 of Set 26 | valparaiso
# Processing Record 40 of Set 26 | marystown
# Processing Record 41 of Set 26 | beaverlodge
# Processing Record 42 of Set 26 | harper
# Processing Record 43 of Set 26 | atar
# Processing Record 44 of Set 26 | falealupo
# City not found. Skipping...
# Processing Record 45 of Set 26 | ye
# City not found. Skipping...
# Processing Record 46 of Set 26 | kempele
# Processing Record 47 of Set 26 | saint-augustin
# Processing Record 48 of Set 26 | cockburn harbour
# City not found. Skipping...
# Processing Record 49 of Set 26 | beringovskiy
# Processing Record 50 of Set 26 | taburbah
# City not found. Skipping...
# Processing Record 1 of Set 27 | vernon
# Processing Record 2 of Set 27 | caibarien
# Processing Record 3 of Set 27 | aldan
# Processing Record 4 of Set 27 | san rafael
# Processing Record 5 of Set 27 | camacha
# Processing Record 6 of Set 27 | nizhnyaya omka
# Processing Record 7 of Set 27 | anlu
# Processing Record 8 of Set 27 | rosario oeste
# Processing Record 9 of Set 27 | arrecife
# Processing Record 10 of Set 27 | shangzhi
# Processing Record 11 of Set 27 | mathbaria
# Processing Record 12 of Set 27 | mandalgovi
# Processing Record 13 of Set 27 | zhigansk
# Processing Record 14 of Set 27 | matagami
# Processing Record 15 of Set 27 | khartoum
# Processing Record 16 of Set 27 | galveston
# Processing Record 17 of Set 27 | ghosi
# Processing Record 18 of Set 27 | haines junction
# Processing Record 19 of Set 27 | bogande
# Processing Record 20 of Set 27 | trzacka rastela
# Processing Record 21 of Set 27 | najran
# Processing Record 22 of Set 27 | margate
# Processing Record 23 of Set 27 | ailigandi
# Processing Record 24 of Set 27 | huaihua
# Processing Record 25 of Set 27 | muisne
# Processing Record 26 of Set 27 | tabuk
# Processing Record 27 of Set 27 | mirnyy
# Processing Record 28 of Set 27 | sioux lookout
# Processing Record 29 of Set 27 | laguna
# Processing Record 30 of Set 27 | simao
# Processing Record 31 of Set 27 | sribne
# Processing Record 32 of Set 27 | galesong
# Processing Record 33 of Set 27 | barentu
# Processing Record 34 of Set 27 | gualaquiza
# Processing Record 35 of Set 27 | galgani
# City not found. Skipping...
# Processing Record 36 of Set 27 | sitka
# Processing Record 37 of Set 27 | peniche
# Processing Record 38 of Set 27 | seydi
# Processing Record 39 of Set 27 | porto santo
# Processing Record 40 of Set 27 | sergeyevka
# Processing Record 41 of Set 27 | rudnogorsk
# Processing Record 42 of Set 27 | luxor
# Processing Record 43 of Set 27 | huty
# Processing Record 44 of Set 27 | plettenberg bay
# Processing Record 45 of Set 27 | toba
# Processing Record 46 of Set 27 | newport
# Processing Record 47 of Set 27 | leningradskiy
# Processing Record 48 of Set 27 | antunez
# Processing Record 49 of Set 27 | ciudad guayana
# Processing Record 50 of Set 27 | klyuchi
# Processing Record 1 of Set 28 | lakatoro
# Processing Record 2 of Set 28 | sassandra
# Processing Record 3 of Set 28 | cairns
# Processing Record 4 of Set 28 | wynyard
# Processing Record 5 of Set 28 | porbandar
# Processing Record 6 of Set 28 | acarau
# Processing Record 7 of Set 28 | pangkalanbuun
# Processing Record 8 of Set 28 | grand gaube
# Processing Record 9 of Set 28 | kolkwitz
# Processing Record 10 of Set 28 | okha
# Processing Record 11 of Set 28 | kiunga
# Processing Record 12 of Set 28 | magistralnyy
# Processing Record 13 of Set 28 | kathmandu
# Processing Record 14 of Set 28 | mogadishu
# Processing Record 15 of Set 28 | yirol
# City not found. Skipping...
# Processing Record 16 of Set 28 | reconquista
# Processing Record 17 of Set 28 | twentynine palms
# Processing Record 18 of Set 28 | port hedland
# Processing Record 19 of Set 28 | siva
# Processing Record 20 of Set 28 | colac
# Processing Record 21 of Set 28 | maizuru
# Processing Record 22 of Set 28 | balikpapan
# Processing Record 23 of Set 28 | nguiu
# City not found. Skipping...
# Processing Record 24 of Set 28 | ha tinh
# Processing Record 25 of Set 28 | trutnov
# Processing Record 26 of Set 28 | stavern
# Processing Record 27 of Set 28 | ketovo
# Processing Record 28 of Set 28 | bodhan
# Processing Record 29 of Set 28 | auki
# Processing Record 30 of Set 28 | progreso
# Processing Record 31 of Set 28 | ankazobe
# Processing Record 32 of Set 28 | hinton
# Processing Record 33 of Set 28 | ngorongoro
# Processing Record 34 of Set 28 | kuju
# Processing Record 35 of Set 28 | hambantota
# Processing Record 36 of Set 28 | baie-comeau
# Processing Record 37 of Set 28 | asau
# Processing Record 38 of Set 28 | sao desiderio
# Processing Record 39 of Set 28 | stornoway
# Processing Record 40 of Set 28 | hofn
# Processing Record 41 of Set 28 | karratha
# Processing Record 42 of Set 28 | puerto quijarro
# Processing Record 43 of Set 28 | novichikha
# Processing Record 44 of Set 28 | lodwar
# Processing Record 45 of Set 28 | cotonou
# Processing Record 46 of Set 28 | hailar
# Processing Record 47 of Set 28 | lensk
# Processing Record 48 of Set 28 | port hardy
# Processing Record 49 of Set 28 | soe
# Processing Record 50 of Set 28 | nong chik
# Processing Record 1 of Set 29 | preeceville
# Processing Record 2 of Set 29 | tandil
# Processing Record 3 of Set 29 | evensk
# Processing Record 4 of Set 29 | russell
# Processing Record 5 of Set 29 | ust-barguzin
# Processing Record 6 of Set 29 | gradistea
# Processing Record 7 of Set 29 | hashtgerd
# Processing Record 8 of Set 29 | eldikan
# City not found. Skipping...
# Processing Record 9 of Set 29 | ofunato
# Processing Record 10 of Set 29 | makubetsu
# Processing Record 11 of Set 29 | vila franca do campo
# Processing Record 12 of Set 29 | ilulissat
# Processing Record 13 of Set 29 | makurdi
# Processing Record 14 of Set 29 | saint-georges
# Processing Record 15 of Set 29 | mackay
# Processing Record 16 of Set 29 | awjilah
# Processing Record 17 of Set 29 | harnosand
# Processing Record 18 of Set 29 | loei
# Processing Record 19 of Set 29 | choloma
# Processing Record 20 of Set 29 | andros town
# Processing Record 21 of Set 29 | ler
# Processing Record 22 of Set 29 | champerico
# Processing Record 23 of Set 29 | douglas
# Processing Record 24 of Set 29 | soligalich
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             Port Alfred -33.5906   26.8910     68.00        87          39
# 1                  Padang  -0.9492  100.3543     78.80        73          20
# 2                  Yulara -25.2406  130.9889     86.00        23           1
# 3            Ponta Do Sol  32.6667  -17.1000     54.00        67          12
# 4               Busselton -33.6500  115.3333     61.00        96         100
# 5  Oliveira Dos Brejinhos -12.3169  -42.8961     70.95        91         100
# 6                 Ushuaia -54.8000  -68.3000     50.00        76          75
# 7              Chokurdakh  70.6333  147.9167    -20.72        86         100
# 8                Upington -28.4478   21.2561     75.51        35           0
# 9                 Xichang  27.8964  102.2634     44.67        58           0
#
#    Wind Speed Country Current Description
# 0        5.99      ZA    scattered clouds
# 1        2.30      ID          few clouds
# 2       17.27      AU           clear sky
# 3        1.99      PT          few clouds
# 4        3.00      AU          light rain
# 5        2.80      BR       moderate rain
# 6       12.66      AR       broken clouds
# 7        3.58      RU     overcast clouds
# 8        7.70      ZA           clear sky
# 9        1.72      CN           clear sky

# %%
new_column_order = ["City", "Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                      City Country      Lat       Lng  Max Temp  Humidity  \
# 0             Port Alfred      ZA -33.5906   26.8910     68.00        87
# 1                  Padang      ID  -0.9492  100.3543     78.80        73
# 2                  Yulara      AU -25.2406  130.9889     86.00        23
# 3            Ponta Do Sol      PT  32.6667  -17.1000     54.00        67
# 4               Busselton      AU -33.6500  115.3333     61.00        96
# 5  Oliveira Dos Brejinhos      BR -12.3169  -42.8961     70.95        91
# 6                 Ushuaia      AR -54.8000  -68.3000     50.00        76
# 7              Chokurdakh      RU  70.6333  147.9167    -20.72        86
# 8                Upington      ZA -28.4478   21.2561     75.51        35
# 9                 Xichang      CN  27.8964  102.2634     44.67        58
#
#    Cloudiness  Wind Speed Current Description
# 0          39        5.99    scattered clouds
# 1          20        2.30          few clouds
# 2           1       17.27           clear sky
# 3          12        1.99          few clouds
# 4         100        3.00          light rain
# 5         100        2.80       moderate rain
# 6          75       12.66       broken clouds
# 7         100        3.58     overcast clouds
# 8           0        7.70           clear sky
# 9           0        1.72           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
